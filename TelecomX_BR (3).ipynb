# %% [markdown]
# #📌 Extracão

# %%
import requests
import pandas as pd

url = 'https://raw.githubusercontent.com/alura-cursos/challenge2-data-science/refs/heads/main/TelecomX_Data.json'
response = requests.get(url)
data = response.json()
df = pd.DataFrame(data)

print(df.head())
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %% [markdown]
# #🔧 Transformação

# %%
from pandas import json_normalize

df = json_normalize(data)
df.head()
# Out:
#    customerID Churn customer.gender  customer.SeniorCitizen customer.Partner  \
# 0  0002-ORFBO    No          Female                       0              Yes
# 1  0003-MKNFE    No            Male                       0               No
# 2  0004-TLHLJ   Yes            Male                       0               No
# 3  0011-IGKFF   Yes            Male                       1              Yes
# 4  0013-EXCHZ   Yes          Female                       1              Yes
#
#   customer.Dependents  customer.tenure phone.PhoneService phone.MultipleLines  \
# 0                 Yes                9                Yes                  No
# 1                  No                9                Yes                 Yes
# 2                  No                4                Yes                  No
# 3                  No               13                Yes                  No
# 4                  No                3                Yes                  No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7267 non-null   object
#  1   Churn                      7267 non-null   object
#  2   customer.gender            7267 non-null   object
#  3   customer.SeniorCitizen     7267 non-null   int64
#  4   customer.Partner           7267 non-null   object
#  5   customer.Dependents        7267 non-null   object
#  6   customer.tenure            7267 non-null   int64
#  7   phone.PhoneService         7267 non-null   object
#  8   phone.MultipleLines        7267 non-null   object
#  9   internet.InternetService   7267 non-null   object
#  10  internet.OnlineSecurity    7267 non-null   object
#  11  internet.OnlineBackup      7267 non-null   object
#  12  internet.DeviceProtection  7267 non-null   object
# ...

# %%
df = pd.read_json(url)
df.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
df.columns
# Out:
# Index(['customerID', 'Churn', 'customer', 'phone', 'internet', 'account'], dtype='object')

# %%
customer_expanded = json_normalize(df['customer'])

# %%
df = pd.concat([df.drop('customer', axis=1), customer_expanded], axis=1)

# %%
phone_expanded = json_normalize(df['phone'])
df = pd.concat([df.drop('phone', axis=1), phone_expanded], axis=1)

# %%
internet_expanded = json_normalize(df['internet'])
df = pd.concat([df.drop('internet', axis=1), internet_expanded], axis=1)

# %%
account_expanded = json_normalize(df['account'])
df = pd.concat([df.drop('account', axis=1), account_expanded], axis=1)

# %%
df.isnull().sum()
# Out:
# customerID          0
# Churn               0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# Charges.Monthly     0
# Charges.Total       0
# dtype: int64

# %%
print(df['Churn'].nunique())
df.describe(include='all')
df.isnull().sum()
# Out:
# 3
# customerID          0
# Churn               0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# Charges.Monthly     0
# Charges.Total       0
# dtype: int64

# %%
colunas_relevantes = ['customerID', 'Churn', 'gender', 'SeniorCitizen', 'InternetService', 'Contract', 'Charges.Monthly']
df_relevante = df[colunas_relevantes]
df_relevante.head()
# Out:
#    customerID Churn  gender  SeniorCitizen InternetService        Contract  \
# 0  0002-ORFBO    No  Female              0             DSL        One year
# 1  0003-MKNFE    No    Male              0             DSL  Month-to-month
# 2  0004-TLHLJ   Yes    Male              0     Fiber optic  Month-to-month
# 3  0011-IGKFF   Yes    Male              1     Fiber optic  Month-to-month
# 4  0013-EXCHZ   Yes  Female              1     Fiber optic  Month-to-month
#
#    Charges.Monthly
# 0             65.6
# 1             59.9
# 2             73.9
# 3             98.0
# 4             83.9

# %%
df['Charges.Monthly'].fillna(df['Charges.Monthly'].mean(), inplace=True)
df['Churn'].unique()
# Out:
# /tmp/ipython-input-43-2151725621.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Charges.Monthly'].fillna(df['Charges.Monthly'].mean(), inplace=True)
# array(['No', 'Yes', ''], dtype=object)

# %% [markdown]
# #📊 Carga e análise

# %%
df.describe(include='all')
# Out:
#         customerID Churn gender  SeniorCitizen Partner Dependents  \
# count         7267  7267   7267    7267.000000    7267       7267
# unique        7267     3      2            NaN       2          2
# top     9995-HOTOH    No   Male            NaN      No         No
# freq             1  5174   3675            NaN    3749       5086
# mean           NaN   NaN    NaN       0.162653     NaN        NaN
# std            NaN   NaN    NaN       0.369074     NaN        NaN
# min            NaN   NaN    NaN       0.000000     NaN        NaN
# 25%            NaN   NaN    NaN       0.000000     NaN        NaN
# 50%            NaN   NaN    NaN       0.000000     NaN        NaN
# 75%            NaN   NaN    NaN       0.000000     NaN        NaN
# max            NaN   NaN    NaN       1.000000     NaN        NaN
#
#              tenure PhoneService MultipleLines InternetService  ...  \
# count   7267.000000         7267          7267            7267  ...
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(x='Churn', data=df)
plt.title('Distribuição de Churn')
plt.show()

# %%
sns.boxplot(x='Churn', y='Charges.Monthly', data=df)
plt.title('Charges.Monthly vs Churn')
plt.show()

# %%
numerical_columns = df.select_dtypes(include=['float64', 'int64'])
print(numerical_columns.head())
# Out:
#    SeniorCitizen  tenure  Charges.Monthly
# 0              0       9             65.6
# 1              0       9             59.9
# 2              0       4             73.9
# 3              1      13             98.0
# 4              1       3             83.9

# %%
correlation = numerical_columns.corr()
sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title('Correlação entre Variáveis Numéricas')
plt.show()

# %%
df['Charges.Monthly'] = pd.to_numeric(df['Charges.Monthly'], errors='coerce')

# %%
num_cols = df.select_dtypes(include=['float64', 'int64'])
desc = num_cols.describe().T
desc['median'] = num_cols.median()
desc[['mean', 'median', 'std', 'min', '25%', '50%', '75%', 'max']]
# Out:
#                       mean  median        std    min     25%   50%     75%  \
# SeniorCitizen     0.162653     0.0   0.369074   0.00   0.000   0.0   0.000
# tenure           32.346498    29.0  24.571773   0.00   9.000  29.0  55.000
# Charges.Monthly  64.720098    70.3  30.129572  18.25  35.425  70.3  89.875
#
#                     max
# SeniorCitizen      1.00
# tenure            72.00
# Charges.Monthly  118.75

# %%
categorical_vars = ['gender', 'Contract', 'PaymentMethod']  # Ajuste conforme suas colunas

for var in categorical_vars:
    print(f"Valores únicos em {var}: {df[var].unique()}\n")
# Out:
# Valores únicos em gender: ['Female' 'Male']
#
# Valores únicos em Contract: ['One year' 'Month-to-month' 'Two year']
#
# Valores únicos em PaymentMethod: ['Mailed check' 'Electronic check' 'Credit card (automatic)'
#  'Bank transfer (automatic)']

# %%
for var in categorical_vars:
    churn_by_var = df.groupby([var, 'Churn']).size().unstack(fill_value=0)
    churn_by_var['Total'] = churn_by_var.sum(axis=1)
    churn_by_var['Churn_Rate_%'] = (churn_by_var.get('Yes', 0) / churn_by_var['Total']) * 100
    print(f"Churn por {var}:\n", churn_by_var, "\n")
# Out:
# Churn por gender:
#  Churn          No  Yes  Total  Churn_Rate_%
# gender
# Female  104  2549  939   3592     26.141425
# Male    120  2625  930   3675     25.306122
#
# Churn por Contract:
#  Churn                  No   Yes  Total  Churn_Rate_%
# Contract
# Month-to-month  130  2220  1655   4005     41.323346
# One year         46  1307   166   1519     10.928242
# Two year         48  1647    48   1743      2.753873
#
# Churn por PaymentMethod:
#  Churn                            No   Yes  Total  Churn_Rate_%
# PaymentMethod
# Bank transfer (automatic)  45  1286   258   1589     16.236627
# Credit card (automatic)    46  1290   232   1568     14.795918
# Electronic check           80  1294  1071   2445     43.803681
# Mailed check               53  1304   308   1665     18.498498

# %%
for var in categorical_vars:
    plt.figure(figsize=(8,4))
    sns.countplot(data=df, x=var, hue='Churn')
    plt.title(f'Churn por {var}')
    plt.xticks(rotation=45)
    plt.show()

# %%
churn_by_gender = df.groupby(['gender', 'Churn']).size().unstack(fill_value=0)
churn_by_gender['Total'] = churn_by_gender.sum(axis=1)
churn_by_gender['Churn_Rate_%'] = (churn_by_gender.get('Yes', 0) / churn_by_gender['Total']) * 100
print(churn_by_gender)
# Out:
# Churn          No  Yes  Total  Churn_Rate_%
# gender
# Female  104  2549  939   3592     26.141425
# Male    120  2625  930   3675     25.306122

# %% [markdown]
# #📄Relatorio Final

# %% [markdown]
# # **Conclusões e Insights**

# %% [markdown]
# - Clientes com contrato mensal têm uma taxa de evasão muito maior, indicando que contratos mais longos tendem a fidelizar melhor.
# - O método de pagamento via cheque eletrônico apresenta uma taxa de evasão muito alta, sugerindo necessidade de revisão nas políticas ou processos relacionados.
# - O gênero do cliente não aparenta influenciar significativamente a evasão.

# %% [markdown]
# # **Recomendações**
#
#
# - Incentivar os clientes a optarem por contratos anuais ou bienais.
# - Avaliar melhorias no método de pagamento via cheque eletrônico para aumentar retenção.
# - Direcionar campanhas de retenção mais específicas para os clientes de contrato mensal.
